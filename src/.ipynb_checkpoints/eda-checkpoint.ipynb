# %% [markdown]
# # Birdcall identification exploratory data analysis
# ## File and data exploration
# First we'll explore the different type of files that are provided to use through the cornell dataset, we can distinguish between csv files that contain sound metadata and mp3 that contain the sound of the birds.

# %%
import pandas as pd # csv reading and metadata parsing 
import numpy as np # for numerical computation
import matplotlib.pyplot as plt # for data analysis and plotting 
import utils.stats as stats # utility functions for data exploration 
import utils.filesystem as filesystem # utility functions and file/path variables
import librosa # mp3 reading

# %% [markdown]
# #### Sample submission
# As a sample submission we have a csv that contains two cols. In each row we must specify which
# birds are singing, the quantity of birds can vary from 0 to n where n is the number of classes,
# although it might be very improbable

# %%
sample_sub = pd.read_csv(filesystem.sample_submission_file)
sample_sub
# Out:
#                                        row_id   birds
# 0   site_1_0a997dff022e3ad9744d4e7bbf923288_5  nocall
# 1  site_1_0a997dff022e3ad9744d4e7bbf923288_10  nocall
# 2  site_1_0a997dff022e3ad9744d4e7bbf923288_15  nocall

# %% [markdown]
# #### Train metadata
# For the train metadata we have a lot of variables, variables such as channels, date, rating, are self explainable, others such as playback_used and url don't seem to have a real value to the training. For the training we must make a selection of the importance of specific variables based on the few that are provided in the test set. The most important variable is the ebird_code, this code identifies a specific bird. Each training sample can only contain a single bird due to the small size of the sample, on the other hand the test set might contain very large sequences of data. Concequently we must find a way to dividie the data into smaller, more managable chunks. Following we analyse some specific features more deeply

# %%
train_meta = pd.read_csv(filesystem.train_file)
train_meta
# Out:
#        rating playback_used ebird_code    channels        date          pitch  \
# 0         3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3         3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4         4.0            no     aldfly  2 (stereo)  2013-05-27           both
# ...       ...           ...        ...         ...         ...            ...
# 21370     4.5            no     yetvir    1 (mono)  2019-05-15           both
# 21371     3.5            no     yetvir    1 (mono)  2017-05-14  Not specified
# 21372     5.0            no     yetvir    1 (mono)  2017-06-10  Not specified
# 21373     3.5            no     yetvir  2 (stereo)  2009-05-06          level
# 21374     3.5            no     yetvir  2 (stereo)  2010-06-09          level
#
#        duration      filename          speed                species  ...  \
# 0            25  XC134874.mp3  Not specified       Alder Flycatcher  ...
# 1            36  XC135454.mp3           both       Alder Flycatcher  ...
# 2            39  XC135455.mp3           both       Alder Flycatcher  ...
# 3            33  XC135456.mp3           both       Alder Flycatcher  ...
# 4            36  XC135457.mp3          level       Alder Flycatcher  ...
# ...         ...           ...            ...                    ...  ...
# 21370        28  XC477608.mp3          level  Yellow-throated Vireo  ...
# 21371        52  XC500348.mp3  Not specified  Yellow-throated Vireo  ...
# 21372        96  XC501230.mp3  Not specified  Yellow-throated Vireo  ...
# 21373        35   XC54828.mp3          level  Yellow-throated Vireo  ...
# 21374       103   XC55761.mp3          level  Yellow-throated Vireo  ...
#
#         xc_id                                url        country  \
# 0      134874  https://www.xeno-canto.org/134874  United States
# 1      135454  https://www.xeno-canto.org/135454  United States
# 2      135455  https://www.xeno-canto.org/135455  United States
# 3      135456  https://www.xeno-canto.org/135456  United States
# 4      135457  https://www.xeno-canto.org/135457  United States
# ...       ...                                ...            ...
# 21370  477608  https://www.xeno-canto.org/477608  United States
# 21371  500348  https://www.xeno-canto.org/500348  United States
# 21372  501230  https://www.xeno-canto.org/501230  United States
# 21373   54828   https://www.xeno-canto.org/54828  United States
# 21374   55761   https://www.xeno-canto.org/55761  United States
#
#                  author                           primary_label longitude  \
# 0      Jonathon Jongsma      Empidonax alnorum_Alder Flycatcher   -92.962
# 1           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 2           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 3           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# 4           Mike Nelson      Empidonax alnorum_Alder Flycatcher  -82.1106
# ...                 ...                                     ...       ...
# 21370         Sue Riffe  Vireo flavifrons_Yellow-throated Vireo  -84.0131
# 21371     Jacob Saucier  Vireo flavifrons_Yellow-throated Vireo  -77.3422
# 21372     Jacob Saucier  Vireo flavifrons_Yellow-throated Vireo  -77.3422
# 21373       Mike Nelson  Vireo flavifrons_Yellow-throated Vireo  -83.9462
# 21374       Mike Nelson  Vireo flavifrons_Yellow-throated Vireo  -83.5409
#
#               length     time         recordist  \
# 0      Not specified     8:00  Jonathon Jongsma
# 1             0-3(s)    08:30       Mike Nelson
# 2             0-3(s)    08:30       Mike Nelson
# 3             0-3(s)    08:30       Mike Nelson
# 4             0-3(s)    08:30       Mike Nelson
# ...              ...      ...               ...
# 21370         0-3(s)    13:00         Sue Riffe
# 21371  Not specified    15:00     Jacob Saucier
# 21372  Not specified    13:30     Jacob Saucier
# 21373         >10(s)   9:45am       Mike Nelson
# 21374         >10(s)  11:30am       Mike Nelson
#
#                                                  license
# 0            Creative Commons Attribution-ShareAlike 3.0
# 1      Creative Commons Attribution-NonCommercial-Sha...
# 2      Creative Commons Attribution-NonCommercial-Sha...
# 3      Creative Commons Attribution-NonCommercial-Sha...
# 4      Creative Commons Attribution-NonCommercial-Sha...
# ...                                                  ...
# 21370  Creative Commons Attribution-NonCommercial-Sha...
# 21371  Creative Commons Attribution-NonCommercial-Sha...
# 21372  Creative Commons Attribution-NonCommercial-Sha...
# 21373  Creative Commons Attribution-NonCommercial-Sha...
# 21374  Creative Commons Attribution-NonCommercial-Sha...
#
# [21375 rows x 35 columns]

# %%
print(len(train_meta.columns))
print(train_meta.columns)
# Out:
# 35
# Index(['rating', 'playback_used', 'ebird_code', 'channels', 'date', 'pitch',
#        'duration', 'filename', 'speed', 'species', 'number_of_notes', 'title',
#        'secondary_labels', 'bird_seen', 'sci_name', 'location', 'latitude',
#        'sampling_rate', 'type', 'elevation', 'description', 'bitrate_of_mp3',
#        'file_type', 'volume', 'background', 'xc_id', 'url', 'country',
#        'author', 'primary_label', 'longitude', 'length', 'time', 'recordist',
#        'license'],
#       dtype='object')

# %%
bird_codes = train_meta['ebird_code']
total_files = len(bird_codes)
print('Total train files:', total_files)
# Out:
# Total train files: 21375

# %% [markdown]
# As of the total train files we have 21375 files, from which we have the following distribution. The distribution is really disperse with a standard deviation of 25.72, we can see that there at most 100 samples with the same category, the mean is relatively high considering that the minimum number of samples is of 9. There are a total of **264** total bird codes.

# %%
total_codes, values = stats.count_unique(bird_codes)
fig = plt.figure(figsize=(16, 3))
plt.bar(total_codes, values)
plt.show()

# %%
values = np.array(values)
print('Total bird codes:', len(total_codes))
print('Mean count:', values.mean())
print('Variance:', values.var())
print('Standard deviation:', values.std())
print('Min:', values.min())
print('Max:', values.max())
# Out:
# Total bird codes: 264
# Mean count: 80.9659090909091
# Variance: 661.9344438705234
# Standard deviation: 25.728086673332772
# Min: 9
# Max: 100

# %% [markdown]
# #### Test metadata
# As for the test metadata we have only three rows, and from each row we only have 4 variables

# %%
test_meta = pd.read_csv(filesystem.test_file)
test_meta
# Out:
#      site                                      row_id  seconds  \
# 0  site_1   site_1_0a997dff022e3ad9744d4e7bbf923288_5        5
# 1  site_1  site_1_0a997dff022e3ad9744d4e7bbf923288_10       10
# 2  site_1  site_1_0a997dff022e3ad9744d4e7bbf923288_15       15
#
#                            audio_id
# 0  0a997dff022e3ad9744d4e7bbf923288
# 1  0a997dff022e3ad9744d4e7bbf923288
# 2  0a997dff022e3ad9744d4e7bbf923288

# %% [markdown]
# #### Example test metadata

# %%
example_test_meta = pd.read_csv(filesystem.example_test_audio_metadata_file)
example_test_meta
# Out:
#                           file_id        device      date   hour source  \
# 0    BLKFR-10-CPL_20190611_093000  BLKFR-10-CPL  20190611  93000   jack
# 1    ORANGE-7-CAP_20190606_093000  ORANGE-7-CAP  20190606  93000   jack
# 2    BLKFR-10-CPL_20190611_093000  BLKFR-10-CPL  20190611  93000   jack
# 3    BLKFR-10-CPL_20190611_093000  BLKFR-10-CPL  20190611  93000   jack
# 4    ORANGE-7-CAP_20190606_093000  ORANGE-7-CAP  20190606  93000   jack
# ..                            ...           ...       ...    ...    ...
# 250  ORANGE-7-CAP_20190606_093000  ORANGE-7-CAP  20190606  93000   jack
# 251  ORANGE-7-CAP_20190606_093000  ORANGE-7-CAP  20190606  93000   jack
# 252  ORANGE-7-CAP_20190606_093000  ORANGE-7-CAP  20190606  93000   jack
# 253  BLKFR-10-CPL_20190611_093000  BLKFR-10-CPL  20190611  93000   jack
# 254  BLKFR-10-CPL_20190611_093000  BLKFR-10-CPL  20190611  93000   jack
#
#     ebird_code certainty vox_type  time_start    time_end  channel
# 0       westan         c     call    0.255394    0.858845        2
# 1     squirrel         c     call    0.415966    1.410334        1
# 2       gockin         l     call    0.590725    1.944412        2
# 3       mouchi         c     call    1.609081    2.130985        2
# 4       brncre         c     song    2.461655    2.746925        1
# ..         ...       ...      ...         ...         ...      ...
# 250   squirrel         c     call  295.981139  296.559829        2
# 251     westan         c     song  296.614276  299.295811        2
# 252   squirrel         c     call  299.777789  300.592846        2
# 253     yerwar         l     song  458.834619  461.232113        2
# 254     yerwar         l     song  465.847696  467.976083        2
#
# [255 rows x 11 columns]

# %% [markdown]
# #### Example test audio summary

# %%
example_test_summary = pd.read_csv(filesystem.example_test_audio_summary_file)
example_test_summary
# Out:
#                      filename_seconds                   birds      filename  \
# 0      BLKFR-10-CPL_20190611_093000_5    gockin mouchi westan  BLKFR-10-CPL
# 1     BLKFR-10-CPL_20190611_093000_10           gockin westan  BLKFR-10-CPL
# 2     BLKFR-10-CPL_20190611_093000_15           gockin westan  BLKFR-10-CPL
# 3     BLKFR-10-CPL_20190611_093000_20                  mouchi  BLKFR-10-CPL
# 4     BLKFR-10-CPL_20190611_093000_25                  mouchi  BLKFR-10-CPL
# ..                                ...                     ...           ...
# 148  ORANGE-7-CAP_20190606_093000_280         mouqua squirrel  ORANGE-7-CAP
# 149  ORANGE-7-CAP_20190606_093000_285  mouqua squirrel westan  ORANGE-7-CAP
# 150  ORANGE-7-CAP_20190606_093000_290           mouqua westan  ORANGE-7-CAP
# 151  ORANGE-7-CAP_20190606_093000_295         mouqua squirrel  ORANGE-7-CAP
# 152  ORANGE-7-CAP_20190606_093000_300         squirrel westan  ORANGE-7-CAP
#
#      seconds
# 0          5
# 1         10
# 2         15
# 3         20
# 4         25
# ..       ...
# 148      280
# 149      285
# 150      290
# 151      295
# 152      300
#
# [153 rows x 4 columns]

# %% [markdown]
# #### Train audio

# %%
amekes = filesystem.train_audio_files[0]
print('Bird code:', amekes)
sounds = filesystem.listdir_complete(amekes)
print('Total sounds:', len(sounds))
y, sr = librosa.load(sounds[0])
# Out:
# Bird code: ../data/train_audio/amekes
# Total sounds: 75
# /home/pol/PROJECTS/ML/.ai/lib/python3.8/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# #### Example test audio

# %%
y1, sr1 = librosa.load(filesystem.example_audio_files[0])
y2, sr2 = librosa.load(filesystem.example_audio_files[0])
# Out:
# /home/pol/PROJECTS/ML/.ai/lib/python3.8/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/pol/PROJECTS/ML/.ai/lib/python3.8/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
plt.plot(y1)
plt.plot(y2)
plt.show()
